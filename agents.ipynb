# %% [markdown]
# # Coding agents from scratch

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from typing import List, Dict, Callable

# %%
env = load_dotenv()
api_key: str = os.environ.get("OPENAI_API_KEY")

# %%
client = OpenAI(api_key=api_key)

# %%
messages = [
    {
        "role": "developer",
        "content": [{
            "type": "text",
            "text": "You are a helpful assistant who answers in the style of a Southern Belle"
    }]},
    {
        "role": "user",
        "content": [{
            "type": "text",
            "text": "What's the capital of France?"
    }]
    },
]

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
    max_tokens=1000)

# %%
response.choices[0].message.content
# Out:
# 'Well, sugar, the capital of France is just as lovely as a spring bloom in a garden! It’s Paris, the City of Light. Now, isn’t that just delightful? 💖'

# %% [markdown]
# ## Agentic workflows

# %% [markdown]
# ### Prompt-Chaining: Decompose a task into sequential subtasks, where each step builds on previous results

# %% [markdown]
# #### Example 1: Chain workflow for structured data extraction and formatting
# Each step progressively transforms raw text into a formatted table

# %%
data_processing_steps = [
    """Extract only the numerical values and their associated metrics from the text.
    Format each as 'value: metric' on a new line.
    Example format:
    92: customer satisfaction
    45%: revenue growth""",
    
    """Convert all numerical values to percentages where possible.
    If not a percentage or points, convert to decimal (e.g., 92 points -> 92%).
    Keep one number per line.
    Example format:
    92%: customer satisfaction
    45%: revenue growth""",
    
    """Sort all lines in descending order by numerical value.
    Keep the format 'value: metric' on each line.
    Example:
    92%: customer satisfaction
    87%: employee satisfaction""",
    
    """Format the sorted data as a markdown table with columns, without tags or enclosing quotes:
    | Metric | Value |
    |:--|--:|
    | Customer Satisfaction | 92% |"""
]

# %%
class Chainer:
    def __init__(self, system_prompt, steps, inp, model, api_key):
        self.client = OpenAI(api_key=api_key)
        self.steps = steps
        self.inp = inp
        self.model = model
        self.system_prompt = {
            "role": "developer",
            "content": [{
                "type": "text",
                "text": system_prompt
            }]
        }


    def chain(self, verbose=False):
        chain = [self.system_prompt]
        current_input = self.inp
        for ix, step in enumerate(self.steps):            
            new_step = {
                "role": "user",
                "content":
                [{
                    "type": "text",
                    "text":f"{step}\nInput: {current_input}\n"
                }]
            }
            chain.append(new_step)
            response = self.client.chat.completions.create(
                model=self.model,
                messages=chain,
                max_completion_tokens=3000)
            response_content = response.choices[0].message.content
            
            # Add the assistant's response to the chain
            assistant_response = {
                "role": "assistant",
                "content": [{
                    "type": "text",
                    "text": response_content
                }]
            }
            chain.append(assistant_response)
            if verbose:
                print(f"STEP: {ix}")
                print(response_content)
                print("="*36)
            current_input = response_content
        return response_content

# %%
system_prompt = "You are a helpful assistant specializing in marketing analysis."

report = """
Q3 Performance Summary:
Our customer satisfaction score rose to 92 points this quarter.
Revenue grew by 45% compared to last year.
Market share is now at 23% in our primary market.
Customer churn decreased to 5% from 8%.
New user acquisition cost is $43 per user.
Product adoption rate increased to 78%.
Employee satisfaction is at 87 points.
Operating margin improved to 34%.
"""

# %%
chainer1 = Chainer(system_prompt=system_prompt, steps=data_processing_steps, inp=report, model="gpt-4o", api_key=api_key)
out = chainer1.chain(verbose=True)
# Out:
# STEP: 0
# 92: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 43: new user acquisition cost
# 78%: product adoption rate
# 87: employee satisfaction
# 34%: operating margin
# ====================================
# STEP: 1
# 92%: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 4300%: new user acquisition cost
# 78%: product adoption rate
# 87%: employee satisfaction
# 34%: operating margin
# ====================================
# STEP: 2
# 4300%: new user acquisition cost
# 92%: customer satisfaction
# 87%: employee satisfaction
# 78%: product adoption rate
# 45%: revenue growth
# 34%: operating margin
# 23%: market share
# 5%: customer churn
# ====================================
# STEP: 3
# | Metric | Value |
# |:--|--:|
# | New User Acquisition Cost | 4300% |
# | Customer Satisfaction | 92% |
# | Employee Satisfaction | 87% |
# | Product Adoption Rate | 78% |
# | Revenue Growth | 45% |
# | Operating Margin | 34% |
# | Market Share | 23% |
# | Customer Churn | 5% |
# ====================================

# %%
from IPython.display import display, Markdown
display(Markdown(out))
# Out:
# | Metric | Value |
# |:--|--:|
# | New User Acquisition Cost | 4300% |
# | Customer Satisfaction | 92% |
# | Employee Satisfaction | 87% |
# | Product Adoption Rate | 78% |
# | Revenue Growth | 45% |
# | Operating Margin | 34% |
# | Market Share | 23% |
# | Customer Churn | 5% |

# %% [markdown]
# **Expected output**
#
# | Metric | Value |
# |:--|--:|
# | Customer Satisfaction | 92% |
# | Employee Satisfaction | 87% |
# | Product Adoption Rate | 78% |
# | Revenue Growth | 45% |
# | User Acquisition Cost | 43.00 |
# | Operating Margin | 34% |
# | Market Share | 23% |
# | Previous Customer Churn | 8% |
# | Customer Churn | 5% |

# %%
print(out)
# Out:
# | Metric | Value |
# |:--|--:|
# | New User Acquisition Cost | 4300% |
# | Customer Satisfaction | 92% |
# | Employee Satisfaction | 87% |
# | Product Adoption Rate | 78% |
# | Revenue Growth | 45% |
# | Operating Margin | 34% |
# | Market Share | 23% |
# | Customer Churn | 5% |

# %% [markdown]
# #### Example 2: Chain workflow to anonymise, translate and restyle text

# %%
anonymize_and_translate_steps = [
    """"Perform named entity recognition NER on the text, enclosing each entity in the appropriate tag.
    <example>
    Before: 'Mr. Smith went to London, where he met his wife Jane Smith and his partner Leonard Farley'
    After: 'Mr. <LASTNAME>Smith</LASTNAME> went to <CITY>London</CITY>, where he met his wife, <FIRSTNAME>Jane</FIRSTNAME><LASTNAME>Smith</LASTNAME>and his partner<FIRSTNAME>Leonard</FIRSTNAME><LASTNAME>Farley</LASTNAME>
    </example>
    """,
    
    """Anonymize the text, replacing each entity marked with a tag with a pseudonym.
    Make sure to preserve the meaning and content of sentence by replacing each entity with the same pseudonym.
    <example>
    Before: 'Mr. <LASTNAME>Smith</LASTNAME> went to <CITY>London</CITY>, where he met his wife, <FIRSTNAME>Jane</FIRSTNAME><LASTNAME>Smith</LASTNAME>and his partner<FIRSTNAME>Leonard</FIRSTNAME><LASTNAME>Farley</LASTNAME>,
    After: 'Mr. Frum went to Balberry,where he met with his wife, Ellen Frum, and his partner, Algernon Leiter.
    </example>
    """,
    """Translate the anonymized text in Italian.""",
    """Turn the Italian into verses""",
    """Turn the verse into romanesco, in the style of Belli""",
]

# %%
secretary_prompt = "You are a helpful secretary who values confidentiality and is adept at translations"
text = "It was a rainy day in Glasgow, when brothers Chad and John Smith embarked on their journey to Rome, where they hoped they would meet General Tso and his chicken"
chainer2 = Chainer(system_prompt=secretary_prompt, steps=anonymize_and_translate_steps, inp=text, model="gpt-4o", api_key=api_key)
tradit = chainer2.chain()

# %%
tradit
# Out:
# "Era 'na giornata de pioggia a Redford,  \nquanno li fratelli Percy e Rupert Frum,  \nse misero in viaggio, 'ndo và ssòrte er bordo,  \nverso Eldoria, 'n posto tutto fummo.  \n\nDove speraveno d'incontrà er comandante,  \ner Comandante Hawke, omo senza fallo,  \nco' er suo pollo, sempre accanto stante,  \n'n viaggio che sperano nun diventi callo."

# %% [markdown]
# #### Example 3: Chain workflow to create and perfect blog posts

# %%
class Blogger(Chainer):
    def __init__(self, topic, target_audience, word_count, model="gpt-4", api_key=None):
        # Define the system prompt for blog post generation
        system_prompt = """You are a professional blog content creator who specializes in creating
        high-quality, engaging blog posts on various topics. You follow SEO best practices
        and create content that is both informative and engaging."""
        
        # Define the steps for the blog post creation pipeline
        steps = [
            # Step 1: Generate an outline
            """Create a detailed outline for a blog post on the given topic.
            Include a title, introduction, 4-6 main sections with subpoints, and conclusion.
            Format the outline with clear headings and bullet points.""",
            
            # Step 2: Validate and refine the outline
            """Review the outline and ensure it meets these criteria:
            - Covers the topic comprehensively
            - Flows logically from point to point
            - Addresses the needs of the target audience
            - Includes specific, actionable information
            If any criteria are not met, refine the outline accordingly.""",
            
            # Step 3: Expand the outline into a complete post
            """Based on the validated outline, write the complete blog post.
            Include all of the following:
            1. An engaging title
            2. A hook-filled introduction
            3. Well-developed main sections with subheadings
            4. A strong conclusion with a call-to-action
            5. Write in a conversational but professional tone    
            The complete post should be approximately {word_count} words."""
        ]
        
        
        # Prepare input for the chaining process
        input_data = f"""
        Topic: {topic}
        Target Audience: {target_audience}
        Approximate Word Count: {word_count}
        """
        
        # Initialize the parent class
        super().__init__(system_prompt, steps, input_data, model, api_key)
    
    def generate_blog_post(self, verbose=True):
        """Generate a complete blog post using the chaining process"""
        print(f"🚀 Starting blog post generation process...")
        result = self.chain(verbose=verbose)
        print(f"✅ Blog post generation complete!")
        return result
    
    def save_to_file(self, filename):
        """Save the generated blog post to a markdown file"""
        blog_post = self.generate_blog_post(verbose=False)
        with open(filename, 'w') as f:
            f.write(blog_post)
        print(f"📝 Blog post saved to {filename}")

# %%
blogger = Blogger(
    topic="Philosophy of Logic",
    target_audience="advanced undergraduate and graduate students in Philosophy, Computer Science and Mathematics",
    word_count=1400,
    model="gpt-4o-mini",
    api_key=api_key
)
post = blogger.generate_blog_post()
# Out:
# 🚀 Starting blog post generation process...
# STEP: 0
# # Outline for Blog Post: "The Philosophy of Logic: Foundations, Challenges, and Implications"
#
# ## Introduction
# - Brief overview of logic’s integral role in philosophy, computer science, and mathematics.
# - Importance of understanding the philosophical underpinnings of logic.
# - Purpose of the blog post: To explore the philosophy of logic, its key components, challenges, and implications in various fields.
#
# ## I. Defining Logic and Its Philosophical Roots
# ### A. What is Logic?
#    - Traditional definitions of logic.
#    - Difference between formal and informal logic.
# ### B. Historical Context
#    - Contributions of early philosophers: Aristotle’s syllogism, Stoic logic.
#    - Development during the Middle Ages and the Renaissance.
#    - Transition to modern logic: Frege, Russell, and Wittgenstein.
#
# ## II. Types of Logic
# ### A. Classical Logic
#    - Overview of propositional and predicate logic.
#    - Key principles: Law of non-contradiction, Law of excluded middle.
# ### B. Non-Classical Logics
#    - Overview of modal logic, intuitionistic logic, and fuzzy logic.
#    - The philosophical significance of rejecting classical principles.
#
# ## III. The Role of Logic in Philosophy
# ### A. Logic as a Tool for Philosophical Inquiry
#    - How logic aids in constructing philosophical arguments.
#    - Importance of logical consistency in philosophical discourse.
# ### B. Philosophical Implications of Logical Systems
#    - The debate over realism vs. anti-realism.
#    - Implications of Gödel’s incompleteness theorems on philosophical thought.
#
# ## IV. Logic in Computer Science and Mathematics
# ### A. Logical Foundations in Computer Science
#    - Role of logic in programming languages and algorithms.
#    - Logical reasoning in artificial intelligence and machine learning.
# ### B. Mathematical Logic
#    - Use of logic in proofs and mathematical reasoning.
#    - Connectedness between mathematical statements and philosophical implications.
#
# ## V. Challenges in the Philosophy of Logic
# ### A. Paradoxes and Contradictions
#    - Famous logical paradoxes: Russell's paradox, the Liar paradox.
#    - Impact on philosophical theories and logical systems.
# ### B. The Limits of Logic
#    - Discussion on limitations of formal systems.
#    - Philosophical perspectives on what lies beyond logic.
#
# ## VI. Implications for Future Research
# ### A. Interdisciplinary Approaches
#    - Importance of collaborative research between philosophy, mathematics, and computer science.
#    - Emerging trends in logical theory and their applications.
# ### B. Ethical Implications of Logic
#    - The role of logic in decision-making and ethical considerations.
#    - Balancing logical reasoning with human values.
#
# ## Conclusion
# - Summary of the main points discussed.
# - Reflection on the continuing evolution of the philosophy of logic.
# - Call to action for students and researchers to engage with contemporary philosophical debates in logic and its applications.
# ====================================
# STEP: 1
# The outline is already quite comprehensive and well-structured, but I can refine it to ensure that it meets all the specified criteria more effectively. Here are some suggested modifications that enhance the flow, depth, and address the needs of the target audience more directly:
#
# # Refined Outline for Blog Post: "The Philosophy of Logic: Foundations, Challenges, and Implications"
#
# ## Introduction
# - **Overview of Logic's Role**: Explain the significance of logic across philosophy, computer science, and mathematics with real-world examples.
# - **Philosophical Underpinnings**: Discuss why understanding the philosophy of logic is essential for students in these disciplines.
# - **Purpose of the Post**: Clearly state the goal of the blog post: to analyze the philosophy of logic and its relevance in contemporary thought and research.
#
# ## I. Defining Logic and Its Philosophical Roots
# ### A. What is Logic?
#    - **Traditional Definitions**: Provide a few concise definitions from notable philosophers.
#    - **Formal vs. Informal Logic**: Discuss the applications and importance of each type, with examples relevant to philosophy and computer science.
#
# ### B. Historical Context
#    - **Early Contributions**: Highlight key figures like Aristotle and their foundational logic systems.
#    - **Medieval and Renaissance Developments**: Briefly mention figures such as Aquinas and Descartes.
#    - **Modern Logic Transition**: Focus on the pivotal contributions from Frege, Russell, and Wittgenstein, touching on how they shaped contemporary thought.
#
# ## II. Types of Logic
# ### A. Classical Logic
#    - **Propositional vs. Predicate Logic**: Include examples and brief explanations of their significance in mathematical proofs and philosophical arguments.
#    - **Key Principles**: Elaborate on the implications of the Law of non-contradiction and the Law of excluded middle.
#
# ### B. Non-Classical Logics
#    - **Modal, Intuitionistic, and Fuzzy Logic**: Explain each briefly, providing examples that show their application in philosophical and computational contexts.
#    - **Philosophical Significance**: Discuss what the rejection of classical principles means for philosophical discourse.
#
# ## III. The Role of Logic in Philosophy
# ### A. Logic as a Tool for Philosophical Inquiry
#    - **Constructing Arguments**: Include a step-by-step example of how logic is used to construct a philosophical argument.
#    - **Importance of Consistency**: Discuss real-case implications of inconsistencies in philosophical work.
#
# ### B. Philosophical Implications of Logical Systems
#    - **Realism vs. Anti-realism**: Define both positions and their implications in a clear and understandable manner.
#    - **Gödel’s Incompleteness Theorems**: Explain the relevance and impact of these theorems on our understanding of mathematics and philosophy.
#
# ## IV. Logic in Computer Science and Mathematics
# ### A. Logical Foundations in Computer Science
#    - **Programming Languages and Algorithms**: Highlight specific programming languages that leverage logical principles (e.g., Prolog) and their implications for AI.
#    - **AI and Machine Learning**: Discuss how logic forms the backbone of decision-making processes in AI.
#
# ### B. Mathematical Logic
#    - **Use in Proofs and Reasoning**: Provide specific examples of notable proofs that illustrate the intersection of logic and mathematics.
#    - **Philosophical Implications**: Analyze how logical structures can lead to deeper philosophical questions in mathematics.
#
# ## V. Challenges in the Philosophy of Logic
# ### A. Paradoxes and Contradictions
#    - **Explore Key Paradoxes**: Provide a more in-depth exploration of Russell's paradox and the Liar paradox, perhaps even prompting some discussion questions.
#    - **Impact on Theories**: Discuss how these challenges have shaped modern philosophical discourse.
#
# ### B. The Limits of Logic
#    - **Limitations of Formal Systems**: Offer examples of problems that cannot be solved purely through logical systems (e.g., the halting problem).
#    - **Beyond Logic**: Explore philosophical perspectives that emphasize human intuition, emotional reasoning, and decision-making beyond pure logic.
#
# ## VI. Implications for Future Research
# ### A. Interdisciplinary Approaches
#    - **Collaboration between Fields**: Discuss recent interdisciplinary projects that use logic in new and innovative ways.
#    - **Emerging Trends**: Highlight specific trends that advanced students could pursue for future research.
#
# ### B. Ethical Implications of Logic
#    - **Logic in Decision-Making**: Provide scenarios in which logic and ethics intersect and how they affect our choices.
#    - **Balancing Reason and Values**: Address the complexity of incorporating ethical considerations in logical frameworks.
#
# ## Conclusion
# - **Summary**: Recap key points to reinforce understanding.
# - **Evolution of Philosophy of Logic**: Share insights on how logic continues to evolve as new challenges arise.
# - **Call to Action**: Encourage advanced students to engage critically with the subject and consider the intersections of logic, philosophy, and technology in their future research.
#
# ### Note:
# - **Word Count Guidance**: Each section should be appropriately detailed to contribute to the target word count of around 1400 words, with important points expanded upon sufficiently to provide the readers with actionable insights and deeper understandings.
# ====================================
# STEP: 2
# # The Philosophy of Logic: Foundations, Challenges, and Implications
#
# ## Introduction
#
# Logic is the silent architect of our thoughts, the tool that both philosophers and computer scientists wield to construct coherent arguments, interpret reality, and solve complex problems. From Aristotle’s syllogisms to modern computational logic, the journey of logic has shaped much of our understanding of reason and existence. But understanding the philosophy of logic—its foundations, challenges, and implications—is essential, especially for advanced students in philosophy, computer science, and mathematics. This blog post dives into the intricacies of the philosophy of logic, aiming to illuminate how these concepts intertwine across disciplines and the contemporary relevance they hold.
#
# ## I. Defining Logic and Its Philosophical Roots
#
# ### A. What is Logic?
#
# At its core, logic is the systematic study of valid inference, reasoning, and arguments. Notable philosophers, such as Immanuel Kant, defined logic as the rules of thought necessary for coherent discourse. However, it can be further categorized into two primary types: formal and informal logic.
#
# 1. **Formal Logic**: This deals with the structure of arguments. For instance, a syllogism follows a specific format where the conclusion is drawn from two premises. An example is:
#    - All men are mortal. (Premise)
#    - Socrates is a man. (Premise)
#    - Therefore, Socrates is mortal. (Conclusion)
#
# 2. **Informal Logic**: This focuses on the content and context of arguments, evaluating their plausibility and relevance. It's essential for analyzing everyday reasoning, such as in debates or discussions.
#
# ### B. Historical Context
#
# The roots of logic can be traced back to ancient philosophers. Aristotle’s work in the field laid a critical foundation with his development of syllogistic reasoning, a powerful method for structured argumentation. During the Middle Ages, figures like Thomas Aquinas integrated Aristotelian logic with theological concepts. Fast forward to the 19th and 20th centuries, where modern logic was revolutionized by thinkers like Gottlob Frege, Bertrand Russell, and Ludwig Wittgenstein, who shifted our understanding toward symbolic and mathematical logic. Their contributions still resonate in contemporary discussions around logical forms and truth.
#
# ## II. Types of Logic
#
# ### A. Classical Logic
#
# Classical logic is often divided into two branches: propositional and predicate logic.
#
# 1. **Propositional Logic**: This examines the logical relationships between propositions, expressed in statements. For example, the statement “If it rains, then the ground is wet” can be symbolically represented and analyzed for its truth values.
#
# 2. **Predicate Logic**: This extends propositional logic by incorporating quantifiers and variables, enabling a deeper exploration of statements. For instance, “All dogs are mammals” allows assertions about categories rather than isolated propositions.
#
# Key principles underpinning classical logic are the **Law of Non-Contradiction** (a statement cannot be both true and false simultaneously) and the **Law of Excluded Middle** (a statement is either true or false, with no middle ground). These principles are fundamental for philosophical analysis and mathematical proofs.
#
# ### B. Non-Classical Logics
#
# Non-classical logics challenge the foundations laid by classical logic.
#
# 1. **Modal Logic**: This logic introduces modalities—necessity and possibility—allowing us to discuss not only what is but also what might be. For instance, “It is possible for it to rain tomorrow” can be represented and explored within this framework.
#
# 2. **Intuitionistic Logic**: This approach rejects the Law of Excluded Middle, emphasizing constructive proofs. An assertion is only true if it can be constructively proven, leading to a more nuanced understanding of truth.
#
# 3. **Fuzzy Logic**: Often used in computer science and AI, fuzzy logic quantifies truth on a spectrum rather than a binary scale, allowing for reasoning in uncertain or imprecise situations (e.g., “Someone is tall” can vary based on interpretation).
#
# The philosophical significance of these non-classical approaches lies in their challenge to traditional views, urging deeper examination of truth, reality, and the limits of human reasoning.
#
# ## III. The Role of Logic in Philosophy
#
# ### A. Logic as a Tool for Philosophical Inquiry
#
# Logic is not just a tool; it’s a cornerstone of philosophical inquiry. For example, let's consider constructing an argument around the ethics of artificial intelligence:
#
# 1. **Premise 1**: If an AI can make decisions autonomously, then it must be held accountable for its actions.
# 2. **Premise 2**: AI can make decisions autonomously (evidence from autonomous vehicles).
# 3. **Conclusion**: Therefore, AI must be held accountable for its actions.
#
# This structured approach showcases how logic helps clarify complex philosophical dilemmas. Consistency in logical reasoning is paramount; inconsistencies can undermine philosophical claims and lead to confusion or failure in discourse.
#
# ### B. Philosophical Implications of Logical Systems
#
# Logical debates also delve into deeper philosophical questions such as **realism vs. anti-realism**.
#
# - **Realism** posits that certain entities described by mathematical statements exist independently of our knowledge or belief. Conversely, **anti-realism** argues that such entities do not exist outside human conceptual frameworks.
#
# Gödel’s incompleteness theorems further complicate our understanding of logic, demonstrating that within any sufficiently complex system, there are truths that cannot be proven solely through the system's axioms. This has profound implications not only for mathematics but also for philosophical discussions regarding the limits of human knowledge.
#
# ## IV. Logic in Computer Science and Mathematics
#
# ### A. Logical Foundations in Computer Science
#
# Logic underpins many aspects of computer science, particularly in programming languages and algorithms. For example:
#
# - **Prolog**: A logic programming language that uses formal logic to express knowledge and queries. It demonstrates how logical principles can be translated into computer programming.
#
# - **AI & Machine Learning**: Logic is crucial in decision-making processes within AI systems, helping machines assess conditions and make predictions based on logical inference.
#
# ### B. Mathematical Logic
#
# In mathematics, logic serves as the bedrock for proofs and reasoning. Take for example the **proof of the fundamental theorem of algebra**, which establishes that every non-constant polynomial has at least one complex root—a logical assertion based on rigorous proof techniques.
#
# Philosophically, the structures of mathematical logic invite us to explore profound questions around the nature of mathematical truth, existence, and knowledge, demanding that we reflect on what it means for something to be ‘true’ mathematically.
#
# ## V. Challenges in the Philosophy of Logic
#
# ### A. Paradoxes and Contradictions
#
# Philosophical discourse is enriched by the exploration of paradoxes. For instance, **Russell's Paradox** reveals inconsistencies in naive set theory by demonstrating that a set cannot consistently contain itself as a member.
#
# Similarly, the **Liar Paradox** challenges our understanding of truth by asserting a statement that refers to itself, creating a self-referential loop (“This statement is false”). These paradoxes compel philosophers to reconsider the foundations of logical systems and their implications for rational discourse.
#
# ### B. The Limits of Logic
#
# Importantly, formal systems have their limitations; consider the **halting problem**, which proves that no algorithm can universally determine whether a computer program will finish running. Such limitations highlight the confines of logic and provoke discussions on the role of intuition versus pure reasoning in decision-making.
#
# Philosophy also addresses areas beyond logic, emphasizing the importance of emotional reasoning and human experience in understanding complex issues. Sometimes, what lies beyond pure logic is crucial for holistic decision-making.
#
# ## VI. Implications for Future Research
#
# ### A. Interdisciplinary Approaches
#
# Today, interdisciplinary collaborations are transforming the landscape of research. Projects that blend philosophy, mathematics, and computer science, such as those investigating computational ethics in AI, are leading to innovative solutions and deeper understanding.
#
# ### B. Ethical Implications of Logic
#
# The intersection of logic and ethics has become increasingly relevant in modern discourse. For example, ethical reasoning within AI programming raises questions about how we encode moral considerations into algorithms. A scenario where an AI must decide whom to save in an emergency illustrates this clash of logic and moral value.
#
# As we consider these complexities, balancing logical reasoning with human values becomes vital. Engaging with these implications prepares students to navigate the evolving challenges of technology and society.
#
# ## Conclusion
#
# In summary, the philosophy of logic serves as a vital framework not just for understanding arguments but for engaging with the complexities of existence, ethics, and knowledge. As philosophical landscapes evolve, the study of logic remains crucial for fostering critical thinking and guiding future inquiries.
#
# I invite students, researchers, and thinkers alike to engage deeply with these themes. Explore how logic shapes your academic and professional journey, and consider how its principles can be employed to address real-world dilemmas. The interplay between logic, philosophy, and technology presents countless opportunities for exploration—embrace the challenge and contribute to the discourse.
# ====================================
# ✅ Blog post generation complete!

# %%
# display(Markdown(post))

# %% [markdown]
# ### Routing: Dynamically selects specialized LLM paths based on input characteristics

# %%
class LLMPrompt:
    def __init__(self, role, prompt_type, prompt_message):
        return {
            "role": role,
            "content": [{
                "type": prompt_type,
                prompt_type: prompt_message
            }]
        }
            
class LLMAgentSystemPrompt(LLMPrompt):
    def __init__(self, system_prompt):
        super().__init__(role="developer", prompt_type="text", prompt_message=system_prompt)
# Out:
#   Cell In[243], line 11
#     class LLMAgentSystemPrompt(Prompt):
#                                        ^
# SyntaxError: incomplete input

# %%
class LLMAgent:
    def __init__(self, system_prompt, model, api_key):
        self.client = OpenAI(api_key=api_key)
        self.model = model
        self.system_prompt = LLMAgentSystemPrompt(system_prompt)

# %%
class Router(LLMAgent):
    gating_prompt: str
    choices: List[str]
    routes: List[str]

    def __init__(self, system_prompt, choices, routes, model, api_key):
        super().__init__(system_prompt, model, api_key)
